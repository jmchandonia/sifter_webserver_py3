# %%
import sqlite3

# %%
def run_cmd(db_file,cmd):
    conn = sqlite3.connect(db_file)
    c = conn.cursor()
    c.execute(cmd)
    
    result = c.fetchall()

    # We can also close the connection if we are done with it.
    # Just be sure any changes have been committed or they will be lost.
    conn.close()
    #return cPickle.loads(result[0].encode('ascii','ignore'))
    return result

# <codecell>

# %%
cmd="select * from sifter_results limit 1"
db_file="../../../my_dbs/term_db.sqlite3"
run_cmd(db_file,cmd)
# Out:
# [(u'GO:0047128',
#   7768,
#   u'1,2-dehydroreticulinium reductase (NADPH) activity',
#   16.0,
#   0.005,
#   <read-write buffer ptr 0x00000000043C5548, size 37 at 0x00000000043C5510>,
#   <read-write buffer ptr 0x00000000034D3F68, size 63 at 0x00000000034D3F30>)]
