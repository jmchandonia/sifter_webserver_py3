# %%
import sqlite3

# %%
def run_cmd(db_file,cmd):
    conn = sqlite3.connect(db_file)
    c = conn.cursor()
    c.execute(cmd)
    
    result = c.fetchall()

    # We can also close the connection if we are done with it.
    # Just be sure any changes have been committed or they will be lost.
    conn.close()
    #return cPickle.loads(result[0].encode('ascii','ignore'))
    return result

# <codecell>

# %%
cmd="select * from sifter_results limit 1"
db_file="../../../my_dbs/sifter_results_cmp_small.sqlite3"
run_cmd(db_file,cmd)
# Out:
# [(u'A8WRK7_CAEBR',
#   u'A8WRK7',
#   6238,
#   16,
#   597,
#   u'PF03137',
#   6,
#   1462,
#   u'ART_N',
#   <read-write buffer ptr 0x0000000004289E30, size 110 at 0x0000000004289DF8>)]
